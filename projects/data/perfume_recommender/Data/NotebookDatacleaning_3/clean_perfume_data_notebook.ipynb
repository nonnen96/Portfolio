# %% [markdown]
# # Nettoyage des Données de Parfums
#
# Ce notebook explique et exécute le processus de nettoyage des données de parfums à partir d'un fichier Excel.

# %%
import os
import importlib
import clean_perfume_data
importlib.reload(clean_perfume_data)

# Étape 1 : Importation des modules et des fonctions
from clean_perfume_data import clean_perfume_data
import pandas as pd

# Étape 2 : Fichier d'entrée et de sortie
input_file = "perfume_data.xlsx"
output_file = "perfume_data_cleaned.xlsx"

# Étape 3 : Vérification du fichier d'entrée
if not os.path.exists(input_file):
    print(f"Erreur : Le fichier {input_file} est introuvable. Veuillez vérifier.")
else:
    print(f"Fichier d'entrée trouvé : {input_file}")

# Étape 4 : Nettoyage des données
print("=== Début du nettoyage des données ===")
clean_perfume_data(input_file, output_file)
print(f"=== Nettoyage terminé. Données sauvegardées dans {output_file}. ===")

# Étape 5 : Validation des données nettoyées
df_cleaned = pd.read_excel(output_file)
print("Aperçu des données nettoyées :")
print(df_cleaned.head())
print(f"Nombre total de lignes nettoyées : {len(df_cleaned)}")
# Out:
# Fichier d'entrée trouvé : perfume_data.xlsx
# === Début du nettoyage des données ===
# Données nettoyées et sans doublons enregistrées dans : perfume_data_cleaned.xlsx
# === Nettoyage terminé. Données sauvegardées dans perfume_data_cleaned.xlsx. ===
# Aperçu des données nettoyées :
#                                                  URL  \
# 0  https://www.fragrantica.com/perfume/Chanel/All...
# 1  https://www.fragrantica.com/perfume/Yves-Saint...
# 2  https://www.fragrantica.com/perfume/Burberry/B...
# 3  https://www.fragrantica.com/perfume/Maison-Mar...
# 4  https://www.fragrantica.com/perfume/Hugo-Boss/...
#
#                           Perfume                   Brand  \
# 0  Allure Homme Sport Eau Extreme                  Chanel
# 1                     Black Opium      Yves Saint Laurent
# 2             Her Eau de Toilette                Burberry
# 3             Lazy Sunday Morning  Maison Martin Margiela
# 4             Boss Bottled Elixir               Hugo Boss
#
# ...
